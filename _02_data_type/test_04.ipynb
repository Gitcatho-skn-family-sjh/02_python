# %% [markdown]
# 문제 1번
# 3
#
# 문제 2번
# 4

# %%
#문제 1번
fruits ={'apple','banana','cherry'}
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
#문제 2번
animals = {"cat", "dog", "bird", "fish"}
animals.remove("bird")

print(animals)
# Out:
# {'cat', 'fish', 'dog'}

# %%
#문제 3번
set1 = {1,2,3}
set2 = {3,4,5}
sumset=set1.union(set2)
print(sumset)
# Out:
# {1, 2, 3, 4, 5}

# %%
#문제 4번
student = {
    "name": "John",
    "age": 20,
    "major": "Computer Science"
}

print(student["age"])
# Out:
# 20

# %%
#문제 5번

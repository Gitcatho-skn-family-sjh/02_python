# %% [markdown]
# 문제 1번
# 3
#
# 문제 2번
# 4

# %%
#문제 1번
fruits ={'apple','banana','cherry'}
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
#문제 2번
animals = {"cat", "dog", "bird", "fish"}
animals.remove("bird")

print(animals)
# Out:
# {'cat', 'fish', 'dog'}

# %%
#문제 3번
set1 = {1,2,3}
set2 = {3,4,5}
sumset=set1.union(set2)
print(sumset)
# Out:
# {1, 2, 3, 4, 5}

# %%
#문제 4번
student = {
    "name": "John",
    "age": 20,
    "major": "Computer Science"
}

print(student["age"])
# Out:
# 20

# %%
#문제 5번
scores = {
    'math' : 80,
    'english' : 90
}

scores.update({'math' : 95})
print(scores)
# Out:
# {'math': 95, 'english': 90}

# %%
#문제 6번
colors1 = {
    'red' ,
    'blue' ,
    'green'
}
colors2 = {
    'blue',
    'yellow',
    'pink'
}
ans = colors1.intersection(colors2)
print(ans)
# Out:
# {'blue'}

# %%
# 문제 7번
info = {
    'name' : 'alice',
    'age' : 25,
    'city' : 'Seoul'
}
print(info.keys())
print(info.values())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['alice', 25, 'Seoul'])

# %%
# 문제 8번
students = {
    'student1' : 85,
    'student2' : 90,
    'student3' : 95
}
ans = students.pop('student2')
print(ans)
# Out:
# 90

# %%
# 문제 9번

# 아래 조건에 맞는 **셋과 딕셔너리**를 사용하세요.
#
# 1. `numbers`라는 셋에 `{1, 2, 3, 4, 5}`를 저장하세요.
# 2. 딕셔너리 `squares`를 생성하고, 각 숫자를 키로, 숫자의 **제곱값**을 값으로 저장하세요.
# 3. 딕셔너리를 출력하세요.

numbers = {1,2,3,4,5}
squares = {i : i**2 for i in numbers}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 문제 10번

# 다음 조건에 맞는 프로그램을 작성하세요.
#
# 1. 두 셋 `A = {1, 2, 3, 4}`와 `B = {3, 4, 5, 6}`가 있습니다.
# 2. `A`와 `B`의 **대칭 차집합**을 구하세요.
# 3. 결과를 `print()`를 사용해 출력하세요.

A = {1,2,3,4}
B = {3,4,5,6}
ans = A.symmetric_difference(B)
print(ans)
# Out:
# {1, 2, 5, 6}

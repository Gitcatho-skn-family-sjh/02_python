# %%
# 문제 1
num1 = 10
num2 = 5

sum_result = num1 + num2
print(sum_result)
# Out:
# 15

# %%
# 문제 2
x = 7.5
y = 2
result = x / y
print(result)
# Out:
# 3.75

# %%
# 문제 3
is_student = True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
# 문제 4
num1 = 15
num2 = 4

ans1 = num1 % num2
ans2 = num1 // num2
print(ans1)
print(ans2)
# Out:
# 3
# 3

# %%
# 문제 5

greeting_message = "Hello"
greeting_target = "World"
print(greeting_message + greeting_target)
# Out:
# HelloWorld

# %%
# 문제 6
base = 2
exponent = 5

ans = base ** exponent
print(ans)
# Out:
# 32

# %%
# 문제 7
number = 3

print(number % 2)
# Out:
# 1

# %%
# 문제 8
age = 30
city = "Seoul"
print(f"나는 {age}살이고, {city}에 살고 있습니다.")
# Out:
# 나는 30살이고, Seoul에 살고 있습니다.

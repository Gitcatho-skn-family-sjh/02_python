# %%
from zmq.backend import first

# 문제 1
age = 30
name = "신진호"

print(age)
print(name)
# Out:
# 30
# 신진호

# %%
# 문제 2
height = 165
dream = "취뽀"
print(height)
print(dream)
# Out:
# 165
# 취뽀

# %%
# 문제 3
city ="서울"
my_city = city
print(my_city)
print(city)
# Out:
# 서울
# 서울

# %%
# 문제 4
apple_count = 10
orange_count = 20

print(apple_count)
print(orange_count)
# Out:
# 10
# 20

# %%
# 문제 5
first_name = 'shin'
last_name = 'jinho'
full_name = first_name + last_name
print(full_name)
# Out:
# shinjinho
